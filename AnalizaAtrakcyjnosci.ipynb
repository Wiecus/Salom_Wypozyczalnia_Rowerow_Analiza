# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
from tabulate import tabulate
from pymcdm import methods as mcdm_methods
from pymcdm import normalizations as norm
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Przetworzenie danych

# %%
# importing data

dfKult = pd.read_csv('KULT_3881_CTAB_20220211231432.csv', sep=';')
dfLudn = pd.read_csv('LUDN_2425_CTAB_20220211224427.csv', sep=';')
dfTran = pd.read_csv('TRAN_3164_CTAB_20220211231704.csv', sep=';')
dfTury = pd.read_csv('TURY_3186_CTAB_20220211230207.csv', sep=';')
dfWyna = pd.read_csv('WYNA_2497_CTAB_20220211225034.csv', sep=';')

dfKult.fillna(0)
dfLudn.fillna(0)
dfTran.fillna(0)
dfTury.fillna(0)
dfWyna.fillna(0)
# Out:
#          Kod                  Nazwa ogółem;2020;[zł]  Unnamed: 3
# 0     201000   Powiat bolesławiecki          4887,95         0.0
# 1     202000  Powiat dzierżoniowski          4690,20         0.0
# 2     203000       Powiat głogowski          4763,21         0.0
# 3     204000        Powiat górowski          4432,40         0.0
# 4     205000        Powiat jaworski          4932,98         0.0
# ..       ...                    ...              ...         ...
# 375  3217000         Powiat wałecki          4678,73         0.0
# 376  3218000         Powiat łobeski          4713,45         0.0
# 377  3261000      Powiat m.Koszalin          4973,23         0.0
# 378  3262000      Powiat m.Szczecin          5695,84         0.0
# 379  3263000   Powiat m.Świnoujście          5517,68         0.0
#
# [380 rows x 4 columns]

# %%
# changing the names of the columns to be more readable

dfLudn = dfLudn.rename(columns = {'ludność na 1 km2;2020;[osoba]': 'Ludność na 1 km2'}, inplace = False)
dfTran = dfTran.rename(columns = {'ścieżki rowerowe (drogi dla rowerów) ogółem;2020;[km]': 'Ścieżki rowerowe'}, inplace = False)
dfTury = dfTury.rename(columns = {'ogółem;obiekty ogółem;2019;[ob.]': 'Turystyczne obiekty noclegowe'}, inplace = False)
dfWyna = dfWyna.rename(columns = {'ogółem;2020;[zł]': 'Przeciętne wynagrodzenie'}, inplace = False)

# convert commas to dots to enable format to float

dfTran = dfTran.stack().str.replace(',','.').unstack()
dfWyna = dfWyna.stack().str.replace(',','.').unstack()

dfWyna['Przeciętne wynagrodzenie'] = dfWyna['Przeciętne wynagrodzenie'].astype(float)
dfTran['Ścieżki rowerowe'] = dfTran['Ścieżki rowerowe'].astype(float)

dfWyna
# Out:
#      Kod                  Nazwa  Przeciętne wynagrodzenie
# 0    NaN   Powiat bolesławiecki                   4887.95
# 1    NaN  Powiat dzierżoniowski                   4690.20
# 2    NaN       Powiat głogowski                   4763.21
# 3    NaN        Powiat górowski                   4432.40
# 4    NaN        Powiat jaworski                   4932.98
# ..   ...                    ...                       ...
# 375  NaN         Powiat wałecki                   4678.73
# 376  NaN         Powiat łobeski                   4713.45
# 377  NaN      Powiat m.Koszalin                   4973.23
# 378  NaN      Powiat m.Szczecin                   5695.84
# 379  NaN   Powiat m.Świnoujście                   5517.68
#
# [380 rows x 3 columns]

# %%
dfKult = dfKult.drop(labels=['Kod', 'Unnamed: 7'], axis='columns')
dfKult = dfKult.set_index('Nazwa')
dfKult
# Out:
#                        stadiony;ogółem;2018;[ob.]  \
# Nazwa
# Powiat bolesławiecki                           23
# Powiat dzierżoniowski                           6
# Powiat głogowski                                3
# Powiat górowski                                 3
# Powiat jaworski                                 2
# ...                                           ...
# Powiat wałecki                                  6
# Powiat łobeski                                  3
# Powiat m.Koszalin                               3
# Powiat m.Szczecin                               4
# Powiat m.Świnoujście                            1
#
#                        hale sportowe o wymiarach od 36x19 m;ogółem;2018;[ob.]  \
# Nazwa
# Powiat bolesławiecki                                                   1
# Powiat dzierżoniowski                                                  4
# Powiat głogowski                                                       2
# Powiat górowski                                                        2
# Powiat jaworski                                                        0
# ...                                                                  ...
# Powiat wałecki                                                         3
# Powiat łobeski                                                         2
# Powiat m.Koszalin                                                      7
# Powiat m.Szczecin                                                      7
# Powiat m.Świnoujście                                                   0
#
#                        sale gimnastyczne o wymiarach poniżej 36x19 m i sale pomocnicze;ogółem;2018;[ob.]  \
# Nazwa
# Powiat bolesławiecki                                                   0
# Powiat dzierżoniowski                                                  3
# Powiat głogowski                                                       0
# Powiat górowski                                                        1
# Powiat jaworski                                                        0
# ...                                                                  ...
# Powiat wałecki                                                         5
# Powiat łobeski                                                         0
# Powiat m.Koszalin                                                      3
# Powiat m.Szczecin                                                     10
# Powiat m.Świnoujście                                                   1
#
#                        korty tenisowe;ogółem;2018;[ob.]  \
# Nazwa
# Powiat bolesławiecki                                  3
# Powiat dzierżoniowski                                16
# Powiat głogowski                                      5
# Powiat górowski                                       2
# Powiat jaworski                                       1
# ...                                                 ...
# Powiat wałecki                                        7
# Powiat łobeski                                        8
# Powiat m.Koszalin                                    13
# Powiat m.Szczecin                                    11
# Powiat m.Świnoujście                                  6
#
#                        pływalnie kryte;ogółem;2018;[ob.]
# Nazwa
# Powiat bolesławiecki                                   2
# Powiat dzierżoniowski                                  1
# Powiat głogowski                                       2
# Powiat górowski                                        1
# Powiat jaworski                                        1
# ...                                                  ...
# Powiat wałecki                                         1
# Powiat łobeski                                         0
# Powiat m.Koszalin                                      2
# Powiat m.Szczecin                                      3
# Powiat m.Świnoujście                                   1
#
# [380 rows x 5 columns]

# %%
# calculating the average number of sports facilities as a measure of the county's sports activity

dfKult['Średnia ilość obiektów'] = dfKult.mean(axis=1)
dfKult = dfKult.filter(['Średnia ilość obiektów'])
dfKult = dfKult.reset_index()
dfKult
# Out:
#                      Nazwa  Średnia ilość obiektów
# 0     Powiat bolesławiecki                     5.8
# 1    Powiat dzierżoniowski                     6.0
# 2         Powiat głogowski                     2.4
# 3          Powiat górowski                     1.8
# 4          Powiat jaworski                     0.8
# ..                     ...                     ...
# 375         Powiat wałecki                     4.4
# 376         Powiat łobeski                     2.6
# 377      Powiat m.Koszalin                     5.6
# 378      Powiat m.Szczecin                     7.0
# 379   Powiat m.Świnoujście                     1.8
#
# [380 rows x 2 columns]

# %%
# combining a table with data into one

df_merged = pd.merge(dfKult, dfLudn, on=("Nazwa"), how="inner")
df_merged = pd.merge(df_merged, dfTran, on=("Nazwa"), how="inner")
df_merged = pd.merge(df_merged, dfWyna, on=("Nazwa"), how="inner")
df_merged = pd.merge(df_merged, dfTury, on=("Nazwa"), how="inner")

df_merged = df_merged.drop_duplicates(subset=['Nazwa']).reset_index(drop=True)
# Out:
# <ipython-input-23-829562f1d84d>:6: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Kod_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_merged = pd.merge(df_merged, dfTury, on=("Nazwa"), how="inner")

# %%
df_merged = df_merged.drop(labels=['Kod_x', 'Unnamed: 3_x','Kod_y', 'Unnamed: 3_y'], axis='columns')
df_merged
# Out:
#                      Nazwa  Średnia ilość obiektów  Ludność na 1 km2  \
# 0     Powiat bolesławiecki                     5.8                69
# 1    Powiat dzierżoniowski                     6.0               209
# 2         Powiat głogowski                     2.4               200
# 3          Powiat górowski                     1.8                47
# 4          Powiat jaworski                     0.8                86
# ..                     ...                     ...               ...
# 362         Powiat wałecki                     4.4                37
# 363         Powiat łobeski                     2.6                34
# 364      Powiat m.Koszalin                     5.6              1080
# 365      Powiat m.Szczecin                     7.0              1325
# 366   Powiat m.Świnoujście                     1.8               203
#
#      Ścieżki rowerowe  Przeciętne wynagrodzenie  Turystyczne obiekty noclegowe
# 0                57.0                   4887.95                             18
# 1                58.5                   4690.20                             21
# 2                24.4                   4763.21                              8
# 3                 4.7                   4432.40                              1
# 4                10.5                   4932.98                             17
# ..                ...                       ...                            ...
# 362              18.0                   4678.73                             22
# 363               1.6                   4713.45                              6
# 364              88.1                   4973.23                             19
# 365             148.6                   5695.84                             59
# 366              42.7                   5517.68                            103
#
# [367 rows x 6 columns]

# %%
# creating a matrix that will be used for optimization

matrix = df_merged[df_merged.columns[1:]].to_numpy()
print(matrix)
# Out:
# [[5.80000e+00 6.90000e+01 5.70000e+01 4.88795e+03 1.80000e+01]
#  [6.00000e+00 2.09000e+02 5.85000e+01 4.69020e+03 2.10000e+01]
#  [2.40000e+00 2.00000e+02 2.44000e+01 4.76321e+03 8.00000e+00]
#  ...
#  [5.60000e+00 1.08000e+03 8.81000e+01 4.97323e+03 1.90000e+01]
#  [7.00000e+00 1.32500e+03 1.48600e+02 5.69584e+03 5.90000e+01]
#  [1.80000e+00 2.03000e+02 4.27000e+01 5.51768e+03 1.03000e+02]]

# %% [markdown]
# # Indeks: Wypożyczalnia rowerów

# %%
df_merged.columns.tolist()
# Out:
# ['Nazwa',
#  'Średnia ilość obiektów',
#  'Ludność na 1 km2',
#  'Ścieżki rowerowe',
#  'Przeciętne wynagrodzenie',
#  'Turystyczne obiekty noclegowe']

# %%
# assigning weights to columns with values for optimization purposes
# value of weights assigned arbitrarily

weights = np.array([(1/10), (2/10), (3/10), (1/10), (3/10)])
print(weights)
# Out:
# [0.1 0.2 0.3 0.1 0.3]

# %%
# determining the direction of the objective function for each of the columns, in this case all at max

types = np.array([1, 1, 1, 1, 1])

# %%
# calculation of the matrix of results using the TOPSIS method

topsis = mcdm_methods.TOPSIS()
result = topsis(matrix, weights, types)
result
# Out:
# array([0.07110948, 0.07248518, 0.0473739 , 0.02366807, 0.04703679,
#        0.29155968, 0.03298404, 0.22179425, 0.04337638, 0.18259322,
#        0.03578755, 0.02392528, 0.0558176 , 0.05106573, 0.06955963,
#        0.0516758 , 0.05936146, 0.08070684, 0.06000751, 0.0563658 ,
#        0.08601818, 0.0963779 , 0.03354001, 0.06924964, 0.04986113,
#        0.11008433, 0.18295877, 0.41745419, 0.15024995, 0.07486973,
#        0.03863398, 0.15088906, 0.03866119, 0.05366097, 0.04035936,
#        0.08656965, 0.01772231, 0.02180511, 0.03605503, 0.02669775,
#        0.01843757, 0.03363254, 0.07413647, 0.12881773, 0.05601942,
#        0.04404946, 0.051356  , 0.03214965, 0.23782823, 0.17351785,
#        0.22975657, 0.15016579, 0.05872988, 0.05707458, 0.03384947,
#        0.03942425, 0.02832022, 0.02911891, 0.02763914, 0.06784626,
#        0.1018244 , 0.10054382, 0.02622165, 0.02089858, 0.04053723,
#        0.11364839, 0.02398162, 0.0296342 , 0.07718865, 0.07646304,
#        0.07680458, 0.12291495, 0.17421768, 0.29506789, 0.21374361,
#        0.08548859, 0.05950085, 0.05728352, 0.08335472, 0.05449662,
#        0.04601096, 0.04415263, 0.07004744, 0.09401558, 0.0329356 ,
#        0.0762683 , 0.03968966, 0.16251376, 0.10808997, 0.16794158,
#        0.04334855, 0.0235335 , 0.03803504, 0.02930163, 0.05214997,
#        0.03134683, 0.05288052, 0.06691858, 0.03209629, 0.0762238 ,
#        0.0310931 , 0.03225517, 0.05391956, 0.03604098, 0.03859232,
#        0.02648144, 0.06653563, 0.06364594, 0.0128838 , 0.30806496,
#        0.116917  , 0.14538339, 0.04661401, 0.03589654, 0.05920066,
#        0.02906711, 0.04916586, 0.09350707, 0.04605289, 0.02691829,
#        0.04524531, 0.18434268, 0.24833133, 0.04859406, 0.07918841,
#        0.03317185, 0.05109776, 0.0578699 , 0.44402848, 0.05347228,
#        0.06700951, 0.48472747, 0.15091891, 0.17905444, 0.02416246,
#        0.07030933, 0.03974385, 0.03544474, 0.08541752, 0.05668195,
#        0.06736972, 0.10706998, 0.02770842, 0.02819901, 0.02660889,
#        0.05457652, 0.03874657, 0.10892279, 0.20508802, 0.03976523,
#        0.09288729, 0.08789089, 0.06230309, 0.04538702, 0.16845691,
#        0.06811906, 0.03201886, 0.03198796, 0.0396999 , 0.03571733,
#        0.03079035, 0.08063895, 0.0535572 , 0.020957  , 0.11764968,
#        0.03630117, 0.11681342, 0.06832743, 0.02587071, 0.03272914,
#        0.06840263, 0.17030536, 0.17902272, 0.21243116, 0.23972655,
#        0.66100504, 0.03571479, 0.08659451, 0.04531787, 0.07398771,
#        0.04894017, 0.09031528, 0.05865714, 0.04394893, 0.05402255,
#        0.14638105, 0.02495358, 0.05374531, 0.05324681, 0.03923954,
#        0.02338712, 0.03573213, 0.03968528, 0.03628028, 0.08190268,
#        0.05821818, 0.02093788, 0.02679741, 0.02957635, 0.07717594,
#        0.04900318, 0.09532362, 0.01614865, 0.03855732, 0.19063231,
#        0.11494849, 0.13986757, 0.23454963, 0.06959624, 0.08371361,
#        0.12688939, 0.07099017, 0.04509644, 0.07435756, 0.02606672,
#        0.0568346 , 0.03285911, 0.03426895, 0.04156312, 0.03092522,
#        0.03955232, 0.05469322, 0.0385738 , 0.31246936, 0.19422342,
#        0.14229869, 0.06767793, 0.17715511, 0.05660252, 0.09749351,
#        0.11984471, 0.06756184, 0.07202625, 0.18609886, 0.06258147,
#        0.46602526, 0.18118193, 0.07984099, 0.06520273, 0.09092499,
#        0.04319208, 0.36273435, 0.21119769, 0.21142756, 0.23234769,
#        0.07686281, 0.19356779, 0.05728991, 0.04243813, 0.02148901,
#        0.08129466, 0.063973  , 0.03880936, 0.05145648, 0.0854959 ,
#        0.04832754, 0.05416215, 0.06094108, 0.06710821, 0.06559413,
#        0.1211884 , 0.16026899, 0.2297912 , 0.2898789 , 0.16733105,
#        0.10577718, 0.16905625, 0.19045699, 0.10524584, 0.22575269,
#        0.14888235, 0.18045491, 0.10974079, 0.2478951 , 0.21987059,
#        0.31299958, 0.17646226, 0.21365441, 0.10814866, 0.04722429,
#        0.04806056, 0.02023373, 0.1193083 , 0.04827643, 0.02563391,
#        0.07190472, 0.02455856, 0.05114727, 0.04105905, 0.03890172,
#        0.04243891, 0.03590405, 0.20120461, 0.03475446, 0.02649221,
#        0.03111463, 0.03519327, 0.03564913, 0.07802761, 0.07370607,
#        0.04748255, 0.0337014 , 0.10631175, 0.02911141, 0.02882701,
#        0.02843062, 0.08826116, 0.06070445, 0.06573183, 0.04917873,
#        0.02924888, 0.03918851, 0.16309461, 0.22480203, 0.05382125,
#        0.06458224, 0.09541023, 0.0584124 , 0.04365162, 0.03519486,
#        0.04311336, 0.05162514, 0.09127253, 0.0975664 , 0.03084087,
#        0.11780469, 0.03600234, 0.07920665, 0.0549453 , 0.03900529,
#        0.09928409, 0.05831942, 0.21594949, 0.03611908, 0.04263787,
#        0.08800264, 0.03442472, 0.03881655, 0.05203206, 0.07641721,
#        0.04384617, 0.04769838, 0.15752761, 0.11172391, 0.20410814,
#        0.36090422, 0.03990337, 0.03880735, 0.05536748, 0.06668732,
#        0.26214035, 0.06473231, 0.21157269, 0.34003799, 0.25287635,
#        0.04003618, 0.10417466, 0.02665957, 0.2050915 , 0.0846673 ,
#        0.05882664, 0.04109474, 0.04583128, 0.0349964 , 0.14680129,
#        0.21670597, 0.13556613])

# %%
# Convert index back to dataframe

indexWypozyczalnia = pd.DataFrame(result, columns=['Wartość indeksu'])
indexWypozyczalnia['Powiat']= df_merged['Nazwa']
cols = indexWypozyczalnia.columns.tolist()
cols = cols[-1:] + cols[:-1]
indexWypozyczalnia = indexWypozyczalnia[cols]
indexWypozyczalnia
# Out:
#                     Powiat  Wartość indeksu
# 0     Powiat bolesławiecki         0.071109
# 1    Powiat dzierżoniowski         0.072485
# 2         Powiat głogowski         0.047374
# 3          Powiat górowski         0.023668
# 4          Powiat jaworski         0.047037
# ..                     ...              ...
# 362         Powiat wałecki         0.045831
# 363         Powiat łobeski         0.034996
# 364      Powiat m.Koszalin         0.146801
# 365      Powiat m.Szczecin         0.216706
# 366   Powiat m.Świnoujście         0.135566
#
# [367 rows x 2 columns]

# %%
column = indexWypozyczalnia['Wartość indeksu']
max = column.max()

# %%
column = indexWypozyczalnia['Wartość indeksu']
min = column.min()

# %%
# Performing a mathematical operation on the index, thanks to which the best result is 100 and the worst is 0

indexWypozyczalnia["Wartość indeksu"] = (((indexWypozyczalnia["Wartość indeksu"] - min)/(max - min))* 100).round(0).astype(int)
indexWypozyczalnia = indexWypozyczalnia.sort_values(by=["Wartość indeksu"], ascending=False)
indexWypozyczalnia = indexWypozyczalnia.reset_index()
indexWypozyczalnia = indexWypozyczalnia.drop(labels=['index'], axis='columns')

# %%
# creating a ranking of the best five counties

top5Wypozyczalnia = indexWypozyczalnia.head(5)
top5Wypozyczalnia.index += 1
top5Wypozyczalnia = top5Wypozyczalnia.rename(columns = {'Powiat': 'Powiat - Wypożyczalnia rowerów', 'Wartość indeksu': 'Wartość indeksu - Wypożyczalnia rowerów'}, inplace = False)
top5Wypozyczalnia
# Out:
#   Powiat - Wypożyczalnia rowerów  Wartość indeksu - Wypożyczalnia rowerów
# 1         Powiat m. st. Warszawa                                      100
# 2                Powiat m.Kraków                                       73
# 3                   Powiat pucki                                       70
# 4              Powiat tatrzański                                       67
# 5               Powiat m.Wrocław                                       62

# %%
histWypozyczalnia = top5Wypozyczalnia.hist(bins=10, grid=False, figsize=(8,10), layout=(3,1), sharex=True, color='#86bf91', zorder=2, rwidth=0.9)
histWypozyczalnia
# Out:
# array([[<Axes: title={'center': 'Wartość indeksu - Wypożyczalnia rowerów'}>],
#        [<Axes: >],
#        [<Axes: >]], dtype=object)

# %% [markdown]
# # Indeks: Salon rowerowy

# %%
df_merged.columns.tolist()
# Out:
# ['Nazwa',
#  'Średnia ilość obiektów',
#  'Ludność na 1 km2',
#  'Ścieżki rowerowe',
#  'Przeciętne wynagrodzenie',
#  'Turystyczne obiekty noclegowe']

# %%
# all the following operations are analogous to those for bike rentals

weights = np.array([(1.5/10), (2.5/10), (2.5/10), (3.5/10), (0/10)])
print(weights)
# Out:
# [0.15 0.25 0.25 0.35 0.  ]

# %%
types = np.array([1, 1, 1, 1, 1])

# %%
topsis = mcdm_methods.TOPSIS()
result = topsis(matrix, weights, types)
result
# Out:
# array([0.1413411 , 0.12235145, 0.12028591, 0.07389078, 0.13611145,
#        0.08705835, 0.08800366, 0.13684156, 0.12894815, 0.49131994,
#        0.09807396, 0.06280309, 0.12469054, 0.14539762, 0.21521984,
#        0.16353232, 0.17644357, 0.16688076, 0.10595035, 0.07079346,
#        0.2503911 , 0.25293082, 0.09051369, 0.140208  , 0.15776081,
#        0.19871519, 0.25456819, 0.50559288, 0.2700393 , 0.05048381,
#        0.05954958, 0.16349084, 0.08484573, 0.14384625, 0.10633073,
#        0.11815821, 0.03491936, 0.05330975, 0.07643312, 0.06145113,
#        0.0477081 , 0.06096294, 0.1383777 , 0.12134926, 0.06065861,
#        0.11104272, 0.07911772, 0.0571406 , 0.32024735, 0.21169113,
#        0.30574673, 0.21334286, 0.06733851, 0.09509762, 0.06119322,
#        0.08790207, 0.07482226, 0.08876671, 0.05611011, 0.08242311,
#        0.09244032, 0.29882047, 0.04224322, 0.051439  , 0.0839775 ,
#        0.18519026, 0.06831358, 0.07063459, 0.08550005, 0.07327449,
#        0.04441929, 0.16441225, 0.22549868, 0.37436312, 0.28679919,
#        0.15758339, 0.12151831, 0.09427177, 0.11702198, 0.08549631,
#        0.09393686, 0.06067397, 0.10941149, 0.16432219, 0.08280527,
#        0.16039255, 0.07843585, 0.2192805 , 0.19808771, 0.37869889,
#        0.11984171, 0.04207054, 0.12196303, 0.07873951, 0.08359418,
#        0.06600889, 0.11363226, 0.10466078, 0.05347304, 0.22312807,
#        0.07002643, 0.08518415, 0.1194995 , 0.0791727 , 0.06735769,
#        0.04319406, 0.08537691, 0.15951335, 0.0331191 , 0.39881647,
#        0.15388871, 0.20124527, 0.09311778, 0.05957537, 0.14491515,
#        0.07682441, 0.05347509, 0.24346228, 0.04860513, 0.07267682,
#        0.09167991, 0.06937726, 0.10782669, 0.13789186, 0.15421027,
#        0.10046995, 0.08253663, 0.06839812, 0.10397723, 0.09397163,
#        0.15879892, 0.52428797, 0.19536679, 0.29712439, 0.0709916 ,
#        0.14992315, 0.10999022, 0.10069251, 0.23908154, 0.15710657,
#        0.20007604, 0.1742883 , 0.08985388, 0.07993075, 0.07844832,
#        0.11709885, 0.10205969, 0.27673913, 0.18808234, 0.10416664,
#        0.1910251 , 0.17860316, 0.10834649, 0.12468923, 0.32871824,
#        0.11135923, 0.1013525 , 0.10062734, 0.07074695, 0.0851256 ,
#        0.09649677, 0.23361703, 0.12315497, 0.04087734, 0.27218771,
#        0.095204  , 0.17295234, 0.08764303, 0.08299184, 0.07128533,
#        0.16604662, 0.29924797, 0.36895616, 0.28205061, 0.3277889 ,
#        0.77954667, 0.10881644, 0.21947519, 0.11983456, 0.21337513,
#        0.12378149, 0.12238584, 0.09062941, 0.08216124, 0.13136497,
#        0.25227462, 0.05146484, 0.11034493, 0.10155986, 0.09445901,
#        0.05145947, 0.07923524, 0.05532512, 0.06933372, 0.13093151,
#        0.06724297, 0.03761406, 0.05830179, 0.07312247, 0.12618074,
#        0.078316  , 0.1409963 , 0.02810542, 0.11158826, 0.12335669,
#        0.15218698, 0.18185859, 0.31921684, 0.11693111, 0.15125076,
#        0.12307171, 0.20884676, 0.13990205, 0.16677085, 0.07975669,
#        0.16533435, 0.0950779 , 0.08100336, 0.08285127, 0.0862956 ,
#        0.04807995, 0.15428939, 0.11708138, 0.38553306, 0.26246785,
#        0.17511966, 0.13872028, 0.14977098, 0.09845864, 0.16195249,
#        0.11504749, 0.06736643, 0.1359825 , 0.12764456, 0.10145258,
#        0.14385423, 0.13052364, 0.15165178, 0.15469442, 0.11903495,
#        0.11197819, 0.45452082, 0.3378961 , 0.27729177, 0.41147609,
#        0.12474236, 0.12707316, 0.10644691, 0.11075876, 0.03776492,
#        0.11922889, 0.15634886, 0.08981406, 0.11357192, 0.18614478,
#        0.1146536 , 0.13319777, 0.11659782, 0.0978619 , 0.15042872,
#        0.15059589, 0.25583344, 0.31463053, 0.36801591, 0.22543041,
#        0.25670564, 0.33498284, 0.48819066, 0.27288603, 0.40778783,
#        0.25372392, 0.24533944, 0.18893793, 0.32853115, 0.29792273,
#        0.38173143, 0.26665337, 0.30504838, 0.1696604 , 0.06839322,
#        0.14158525, 0.05022848, 0.09772014, 0.08566606, 0.05523162,
#        0.09457082, 0.07539858, 0.14154942, 0.11684438, 0.10875136,
#        0.12463458, 0.11049335, 0.28452742, 0.09554301, 0.07734334,
#        0.04242443, 0.05787212, 0.06882814, 0.08716497, 0.07124527,
#        0.09564195, 0.06720238, 0.0595505 , 0.04841423, 0.02851725,
#        0.07635404, 0.13139103, 0.07950852, 0.10044302, 0.09083864,
#        0.05007565, 0.06391859, 0.23262633, 0.32190632, 0.098724  ,
#        0.13488242, 0.12249597, 0.11519403, 0.05487412, 0.04966527,
#        0.03563022, 0.13537637, 0.07506806, 0.12026578, 0.03455176,
#        0.16180854, 0.08496078, 0.13390789, 0.13114157, 0.08526994,
#        0.16039951, 0.089219  , 0.21540617, 0.07165378, 0.10793068,
#        0.18896883, 0.08270731, 0.06512196, 0.0907724 , 0.09801089,
#        0.11939063, 0.0554626 , 0.21181224, 0.17883467, 0.26897919,
#        0.45584869, 0.10605969, 0.09718035, 0.07843504, 0.16157338,
#        0.07929755, 0.13905118, 0.06839763, 0.1058596 , 0.10870298,
#        0.08601334, 0.22084397, 0.07465377, 0.07399008, 0.12980484,
#        0.13132319, 0.06879035, 0.10793935, 0.10915902, 0.21119399,
#        0.313277  , 0.21085837])

# %%
indexSalon = pd.DataFrame(result, columns=['Wartość indeksu'])
indexSalon['Powiat']= df_merged['Nazwa']
cols = indexSalon.columns.tolist()
cols = cols[-1:] + cols[:-1]
indexSalon = indexSalon[cols]
indexSalon
# Out:
#                     Powiat  Wartość indeksu
# 0     Powiat bolesławiecki         0.141341
# 1    Powiat dzierżoniowski         0.122351
# 2         Powiat głogowski         0.120286
# 3          Powiat górowski         0.073891
# 4          Powiat jaworski         0.136111
# ..                     ...              ...
# 362         Powiat wałecki         0.107939
# 363         Powiat łobeski         0.109159
# 364      Powiat m.Koszalin         0.211194
# 365      Powiat m.Szczecin         0.313277
# 366   Powiat m.Świnoujście         0.210858
#
# [367 rows x 2 columns]

# %%
column = indexSalon['Wartość indeksu']
max = column.max()

# %%
column = indexSalon['Wartość indeksu']
min = column.min()

# %%
indexSalon["Wartość indeksu"] = (((indexSalon["Wartość indeksu"] - min)/(max - min))* 100).round(0).astype(int)
indexSalon = indexSalon.sort_values(by=["Wartość indeksu"], ascending=False)
indexSalon = indexSalon.reset_index()
indexSalon = indexSalon.drop(labels=['index'], axis='columns')

# %%
top5Salon = indexSalon.head(5)
top5Salon.index += 1
top5Salon = top5Salon.rename(columns = {'Powiat': 'Powiat - Salon rowerowy', 'Wartość indeksu': 'Wartość indeksu - Salon rowerowy'}, inplace = False)
top5Salon
# Out:
#      Powiat - Salon rowerowy  Wartość indeksu - Salon rowerowy
# 1     Powiat m. st. Warszawa                               100
# 2            Powiat m.Kraków                                66
# 3           Powiat m.Wrocław                                64
# 4            Powiat lubiński                                62
# 5  Powiat m.Jastrzębie-Zdrój                                61

# %%
histSalon = top5Salon.hist(bins=10, grid=False, figsize=(8,10), layout=(3,1), sharex=True, color='#86bf91', zorder=2, rwidth=0.9)
histSalon
# Out:
# array([[<Axes: title={'center': 'Wartość indeksu - Salon rowerowy'}>],
#        [<Axes: >],
#        [<Axes: >]], dtype=object)

# %% [markdown]
# # Zapis wyników do nowego pliku csv

# %%
# Creating a common table for both indexes

top5Wypozyczalnia['Ranking'] = top5Wypozyczalnia.index
top5Salon['Ranking'] = top5Salon.index

dfResults = pd.merge(top5Wypozyczalnia, top5Salon, on='Ranking')
dfResults = dfResults.set_index('Ranking')
dfResults.head
# Out:
#         Powiat - Wypożyczalnia rowerów  \
# Ranking
# 1               Powiat m. st. Warszawa
# 2                      Powiat m.Kraków
# 3                         Powiat pucki
# 4                    Powiat tatrzański
# 5                     Powiat m.Wrocław
#
#          Wartość indeksu - Wypożyczalnia rowerów    Powiat - Salon rowerowy  \
# Ranking
# 1                                            100     Powiat m. st. Warszawa
# 2                                             73            Powiat m.Kraków
# 3                                             70           Powiat m.Wrocław
# 4                                             67            Powiat lubiński
# 5                                             62  Powiat m.Jastrzębie-Zdrój
#
#          Wartość indeksu - Salon rowerowy
# Ranking
# 1                                     100
# 2                                      66
# 3                                      64
# 4                                      62
# 5                                      61

# %%
# final visualization of the table with indexes

cm = sns.light_palette("green", as_cmap=True)

th_props = [
  ('font-size', '11px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', '#6d6d6d'),
  ('background-color', '#f7f7f9')
  ]


td_props = [
  ('font-size', '11px'),
  ('font-weight', 'bold'),
  ('color', '#000000'),
  ]

styles = [
  dict(selector="th", props=th_props),
  dict(selector="td", props=td_props)
  ]

(dfResults.style
  .background_gradient(cmap=cm, subset=['Wartość indeksu - Wypożyczalnia rowerów','Wartość indeksu - Salon rowerowy'])
  .highlight_max(subset=['Wartość indeksu - Wypożyczalnia rowerów','Wartość indeksu - Salon rowerowy'])
  .set_table_styles(styles))
# Out:
# <style type="text/css">
# #T_f923f th {
#   font-size: 11px;
#   text-align: center;
#   font-weight: bold;
#   color: #6d6d6d;
#   background-color: #f7f7f9;
# }
# #T_f923f td {
#   font-size: 11px;
#   font-weight: bold;
#   color: #000000;
# }
# #T_f923f_row0_col1, #T_f923f_row0_col3 {
#   background-color: #008000;
#   color: #f1f1f1;
#   background-color: yellow;
# }
# #T_f923f_row1_col1 {
#   background-color: #a6d2a6;
#   color: #000000;
# }
# #T_f923f_row1_col3 {
#   background-color: #cde5cd;
#   color: #000000;
# }
# #T_f923f_row2_col1 {
#   background-color: #badbba;
#   color: #000000;
# }
# #T_f923f_row2_col3 {
#   background-color: #d9ead9;
#   color: #000000;
# }
# #T_f923f_row3_col1 {
#   background-color: #cce4cc;
#   color: #000000;
# }
# #T_f923f_row3_col3 {
#   background-color: #e5f0e5;
#   color: #000000;
# }
# #T_f923f_row4_col1, #T_f923f_row4_col3 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# </style>
# <table id="T_f923f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f923f_level0_col0" class="col_heading level0 col0" >Powiat - Wypożyczalnia rowerów</th>
#       <th id="T_f923f_level0_col1" class="col_heading level0 col1" >Wartość indeksu - Wypożyczalnia rowerów</th>
#       <th id="T_f923f_level0_col2" class="col_heading level0 col2" >Powiat - Salon rowerowy</th>
#       <th id="T_f923f_level0_col3" class="col_heading level0 col3" >Wartość indeksu - Salon rowerowy</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ranking</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f923f_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_f923f_row0_col0" class="data row0 col0" >Powiat m. st. Warszawa</td>
#       <td id="T_f923f_row0_col1" class="data row0 col1" >100</td>
#       <td id="T_f923f_row0_col2" class="data row0 col2" >Powiat m. st. Warszawa</td>
#       <td id="T_f923f_row0_col3" class="data row0 col3" >100</td>
#     </tr>
#     <tr>
#       <th id="T_f923f_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_f923f_row1_col0" class="data row1 col0" >Powiat m.Kraków</td>
#       <td id="T_f923f_row1_col1" class="data row1 col1" >73</td>
#       <td id="T_f923f_row1_col2" class="data row1 col2" >Powiat m.Kraków</td>
#       <td id="T_f923f_row1_col3" class="data row1 col3" >66</td>
#     </tr>
#     <tr>
#       <th id="T_f923f_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_f923f_row2_col0" class="data row2 col0" >Powiat pucki</td>
#       <td id="T_f923f_row2_col1" class="data row2 col1" >70</td>
#       <td id="T_f923f_row2_col2" class="data row2 col2" >Powiat m.Wrocław</td>
#       <td id="T_f923f_row2_col3" class="data row2 col3" >64</td>
#     </tr>
#     <tr>
#       <th id="T_f923f_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_f923f_row3_col0" class="data row3 col0" >Powiat tatrzański</td>
#       <td id="T_f923f_row3_col1" class="data row3 col1" >67</td>
#       <td id="T_f923f_row3_col2" class="data row3 col2" >Powiat lubiński</td>
#       <td id="T_f923f_row3_col3" class="data row3 col3" >62</td>
#     </tr>
#     <tr>
#       <th id="T_f923f_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_f923f_row4_col0" class="data row4 col0" >Powiat m.Wrocław</td>
#       <td id="T_f923f_row4_col1" class="data row4 col1" >62</td>
#       <td id="T_f923f_row4_col2" class="data row4 col2" >Powiat m.Jastrzębie-Zdrój</td>
#       <td id="T_f923f_row4_col3" class="data row4 col3" >61</td>
#     </tr>
#   </tbody>
# </table>

# %%
dfResults.to_csv('wyniki.csv', sep='\t')
